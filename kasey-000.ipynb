# %%
import numpy as np
import pandas as pd
import matplotlib.dates as mdates
import matplotlib.pyplot as plt

# %matplotlib inline


df = pd.read_csv('v000.csv')

# %%
df.head()
# Out:
#    time (sec)  X vibration (m/s^2)  Y vibration (m/s^2)  Z vibration (m/s^2)
# 0    0.975865             0.043522            -0.000394            -0.025908
# 1    0.985925             0.016724            -0.009212            -0.125231
# 2    0.995986             0.014161             0.026745            -0.193810
# 3    1.006050             0.084001             0.018754            -0.228238
# 4    1.016110             0.109509            -0.035714            -0.216116

# %%
df.describe()
# Out:
#         time (sec)  X vibration (m/s^2)  Y vibration (m/s^2)  \
# count  1930.000000          1930.000000          1930.000000
# mean     10.679181            -0.000248            -0.000153
# std       5.606568             0.260394             0.281036
# min       0.975865            -0.963991            -1.217160
# 25%       5.827525            -0.139790            -0.164151
# 50%      10.679200             0.015701             0.000566
# 75%      15.530875             0.169136             0.190549
# max      20.382500             0.945969             0.775072
#
#        Z vibration (m/s^2)
# count          1930.000000
# mean              0.001485
# std               1.724089
# min              -4.349680
# 25%              -1.221100
# 50%              -0.092573
# 75%               1.119575
# max               4.537160

# %%
df.plot(x='time (sec)',y='Z vibration (m/s^2)',kind='scatter')

# %%
df.plot(x='time (sec)',y='X vibration (m/s^2)',kind='scatter')

# %%
df.plot(x='time (sec)',y='Y vibration (m/s^2)',kind='scatter')

# %%
df.plot(x='time (sec)',kind='hist')

# %%
df.plot(x='time (sec)',y='Z vibration (m/s^2)',kind='hexbin')

# %%
df.plot(y='Z vibration (m/s^2)',kind='density')

# %%
df.plot(x='time (sec)',kind='line')
